# %%
import pandas as pd

df1 = pd.read_csv(r"D:\SEMESTER 4\BIG DATA\HASIL SCRAPPING\Data_Wikipedia.csv", 
                  on_bad_lines='skip')
df2 = pd.read_csv(r"D:\SEMESTER 4\BIG DATA\HASIL SCRAPPING\scrapping artikel indo (1).csv", 
                  on_bad_lines='skip')

df_gabung = pd.concat([df1, df2], ignore_index=True)

print(f"df1     : {df1.shape}")
print(f"df2     : {df2.shape}")
print(f"Gabungan: {df_gabung.shape}")

df_gabung.to_csv(r"D:\SEMESTER 4\BIG DATA\HASIL SCRAPPING\dataset_gabungan.csv", index=False)
print("Tersimpan: dataset_gabungan.csv")
# Out:
# df1     : (82486038, 3)
# df2     : (42541667, 3)
# Gabungan: (125027705, 3)
# Tersimpan: dataset_gabungan.csv
